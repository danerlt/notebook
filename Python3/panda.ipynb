# %%
import pandas as pd
import numpy as np
df=pd.read_csv(r'H:\notebook\Python3\test.csv', sep=" ")

df.sort_values("start_count",inplace=True, ascending=False)
print(df)
# Out:
#                                              theme_url  start_count  \
# 84       https://github.com/viosey/hexo-theme-material         3577
# 102      https://github.com/theme-next/hexo-theme-next         2366
# 192       https://github.com/yscoder/hexo-theme-indigo         2075
# 68       https://github.com/ppoffice/hexo-theme-icarus         2065
# 90         https://github.com/tufu9441/maupassant-hexo         1888
# 19        https://github.com/pinggod/hexo-theme-apollo         1579
# 145  https://github.com/LouisBarranqueiro/tranquilp...         1456
# 161        https://github.com/MOxFIVE/hexo-theme-yelee         1264
# 26   https://github.com/probberechts/hexo-theme-cactus         1028
# 51            https://github.com/ahonn/hexo-theme-even          989
# 72                   https://github.com/wuchong/jacman          973
# 66       https://github.com/ppoffice/hexo-theme-hueman          949
# 16        https://github.com/haojen/hexo-theme-Anisina          684
# ...
