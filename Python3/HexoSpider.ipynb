# %%
import requests
import json
import csv
import time
from lxml import etree

url = "https://hexo.io/themes/"
# auth = ("username", "password")
auth = ("Lt-grint", "lt1598552894!!!")
theme_xpath = '//*[@id="plugin-list"]/li/a'
# github_api https://api.github.com/repos/用户名/仓库名
github_api = "https://api.github.com/repos/%s"
def get_theme_urls(start="https://github.com"):
    urls = list()
    res = requests.get(url, )
    html = etree.HTML(res.text)
    theme_lis = html.xpath(theme_xpath)
    for theme in theme_lis:
        theme_url = str(theme.get("href"))
#         print("theme_url:%s" % theme_url)
        if theme_url.startswith(start):
            urls.append(theme_url)
    return urls[11:12]       
            
def get_star_fork(url, start="https://github.com"):
    if url.startswith(start):
        req_url = github_api % str(url[len(start):])
        print("github_api req_url :%s" % req_url)
        response = requests.get(req_url, auth=auth)
        # github api 请求有次数限制
        print("response:%s" % response)
        if response.status_code == 200:
            data = json.loads(reponse.text)
            star_count = data.get("stargazers_count")
            watch_count = data.get("watchers_count")
            fork_count = data.get("forks_count")
            result = {
                url: {
                    "star_count": star_count,
                    "watch_count": watch_count,
                    "fork_count": fork_count
                }
            }
            print(result)
            return result
        else:
            raise Exception("http error, errorcode:%s" % response.status_code)
            

def write_datas(datas, filename="test.csv"):            
    with open(filename, 'w', newline='') as csvfile:
        spamwriter = csv.writer(csvfile, delimiter=' ',
                                quotechar='|', quoting=csv.QUOTE_MINIMAL)
        spamwriter.writerow(["url", "start_count", "fork_count", "watch_count"])   
        for data in datas:
            url = data.keys()
            start_count = data.get("star_count")
            fork_count = data.get("fork_count")
            watch_count = data.get("watch_count")
            spamwriter.writerow([url, start_count, fork_count, watch_count])           
    
def main():
    theme_urls  = get_theme_urls()
    datas = list()
    for theme_url in theme_urls:
        try:
            data = get_star_fork(theme_url)
        except Exception as e:
            print(e)
        else:    
            datas.append(data)
        
    print(datas)    
    write_datas(datas)
        
if __name__ == "__main__":
    main()
# Out:
# github_api req_url :https://api.github.com/repos//henryhuang/hexo-theme-aloha
# response:<Response [404]>
# http error, errorcode:404
# []

# %%
import requests
import json


def get_star_fork(url, start="https://github.com"):
    if url.startswith(start):
        req_url = github_api % str(url[len(start):])
        print("github_api req_url :%s" % req_url)
        resp = requests.get(req_url)
        print("resp:%s" % resp)
        data = json.loads(resp.text)
        star_count = data.get("stargazers_count")
        watch_count = data.get("watchers_count")
        fork_count = data.get("forks_count")
        result = {
            url: {
                "star_count": star_count,
                "fork_count": fork_count,
                "fork_count": fork_count
            }
        }
        print(result)
        return result
    
get_star_fork("https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese")

# %% [markdown]
# ## github接口分析：
# 接口地址："https://api.github.com/repos/用户名/仓库名"
# 示例
# github_api = "https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese"
# 返回值格式：
# ```
# {
#   "id": 113177409,
#   "node_id": "MDEwOlJlcG9zaXRvcnkxMTMxNzc0MDk=",
#   "name": "hexo-theme-simple-japanese",
#   "full_name": "mitsuruog/hexo-theme-simple-japanese",
#   "private": false,
#   "owner": {
#     "login": "mitsuruog",
#     "id": 1703219,
#     "node_id": "MDQ6VXNlcjE3MDMyMTk=",
#     "avatar_url": "https://avatars0.githubusercontent.com/u/1703219?v=4",
#     "gravatar_id": "",
#     "url": "https://api.github.com/users/mitsuruog",
#     "html_url": "https://github.com/mitsuruog",
#     "followers_url": "https://api.github.com/users/mitsuruog/followers",
#     "following_url": "https://api.github.com/users/mitsuruog/following{/other_user}",
#     "gists_url": "https://api.github.com/users/mitsuruog/gists{/gist_id}",
#     "starred_url": "https://api.github.com/users/mitsuruog/starred{/owner}{/repo}",
#     "subscriptions_url": "https://api.github.com/users/mitsuruog/subscriptions",
#     "organizations_url": "https://api.github.com/users/mitsuruog/orgs",
#     "repos_url": "https://api.github.com/users/mitsuruog/repos",
#     "events_url": "https://api.github.com/users/mitsuruog/events{/privacy}",
#     "received_events_url": "https://api.github.com/users/mitsuruog/received_events",
#     "type": "User",
#     "site_admin": false
#   },
#   "html_url": "https://github.com/mitsuruog/hexo-theme-simple-japanese",
#   "description": " Hexo blog theme. it makes Japanese more readable and beautiful.",
#   "fork": false,
#   "url": "https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese",
#   "forks_url": "https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese/forks",
#   "keys_url": "https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese/keys{/key_id}",
#   "collaborators_url": "https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese/collaborators{/collaborator}",
#   "teams_url": "https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese/teams",
#   "hooks_url": "https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese/hooks",
#   "issue_events_url": "https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese/issues/events{/number}",
#   "events_url": "https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese/events",
#   "assignees_url": "https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese/assignees{/user}",
#   "branches_url": "https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese/branches{/branch}",
#   "tags_url": "https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese/tags",
#   "blobs_url": "https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese/git/blobs{/sha}",
#   "git_tags_url": "https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese/git/tags{/sha}",
#   "git_refs_url": "https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese/git/refs{/sha}",
#   "trees_url": "https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese/git/trees{/sha}",
#   "statuses_url": "https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese/statuses/{sha}",
#   "languages_url": "https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese/languages",
#   "stargazers_url": "https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese/stargazers",
#   "contributors_url": "https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese/contributors",
#   "subscribers_url": "https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese/subscribers",
#   "subscription_url": "https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese/subscription",
#   "commits_url": "https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese/commits{/sha}",
#   "git_commits_url": "https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese/git/commits{/sha}",
#   "comments_url": "https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese/comments{/number}",
#   "issue_comment_url": "https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese/issues/comments{/number}",
#   "contents_url": "https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese/contents/{+path}",
#   "compare_url": "https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese/compare/{base}...{head}",
#   "merges_url": "https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese/merges",
#   "archive_url": "https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese/{archive_format}{/ref}",
#   "downloads_url": "https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese/downloads",
#   "issues_url": "https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese/issues{/number}",
#   "pulls_url": "https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese/pulls{/number}",
#   "milestones_url": "https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese/milestones{/number}",
#   "notifications_url": "https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese/notifications{?since,all,participating}",
#   "labels_url": "https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese/labels{/name}",
#   "releases_url": "https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese/releases{/id}",
#   "deployments_url": "https://api.github.com/repos/mitsuruog/hexo-theme-simple-japanese/deployments",
#   "created_at": "2017-12-05T12:08:25Z",
#   "updated_at": "2018-11-23T07:30:34Z",
#   "pushed_at": "2018-03-18T23:33:09Z",
#   "git_url": "git://github.com/mitsuruog/hexo-theme-simple-japanese.git",
#   "ssh_url": "git@github.com:mitsuruog/hexo-theme-simple-japanese.git",
#   "clone_url": "https://github.com/mitsuruog/hexo-theme-simple-japanese.git",
#   "svn_url": "https://github.com/mitsuruog/hexo-theme-simple-japanese",
#   "homepage": "https://blog.mitsuruog.info/",
#   "size": 1962,
#   "stargazers_count": 9,
#   "watchers_count": 9,
#   "language": "HTML",
#   "has_issues": true,
#   "has_projects": true,
#   "has_downloads": true,
#   "has_wiki": true,
#   "has_pages": false,
#   "forks_count": 2,
#   "mirror_url": null,
#   "archived": false,
#   "open_issues_count": 0,
#   "license": {
#     "key": "mit",
#     "name": "MIT License",
#     "spdx_id": "MIT",
#     "url": "https://api.github.com/licenses/mit",
#     "node_id": "MDc6TGljZW5zZTEz"
#   },
#   "forks": 2,
#   "open_issues": 0,
#   "watchers": 9,
#   "default_branch": "master",
#   "network_count": 2,
#   "subscribers_count": 0
# }
#
# ```
# 其中start数为：`stargazers_count`，watch数为`watchers_count`，fort数为`watchers_count`。
